# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("parkinson.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0  no_strokes_st  no_strokes_dy  speed_st  speed_dy  \
# 0           0           12.0            2.0  0.000293  0.000431
# 1           1            4.0            6.0  0.000286  0.000281
# 2           2            4.0            4.0  0.000278  0.000277
# 3           3            4.0            4.0  0.000286  0.000275
# 4           4            2.0            2.0  0.000279  0.000270
#
#    magnitude_vel_st  magnitude_horz_vel_st  magnitude_vert_vel_st  \
# 0          0.061342               0.038319               0.039050
# 1          0.119159               0.077012               0.074216
# 2          0.113889               0.071547               0.073336
# 3          0.154621               0.101146               0.096300
# 4          0.060058               0.039449               0.036737
#
#    magnitude_vel_dy  magnitude_horz_vel_dy  ...  magnitude_horz_jerk_dy  \
# 0          0.084891               0.053885  ...                0.000006
# ...

# %%
df1.tail()
# Out:
#     Unnamed: 0  no_strokes_st  no_strokes_dy  speed_st  speed_dy  \
# 72          72            2.0            2.0  0.001592  0.001560
# 73          73            2.0            2.0  0.001387  0.001339
# 74          74           48.0          176.0  0.001201  0.001194
# 75          75            6.0           10.0  0.001159  0.001157
# 76          76            0.0            0.0  0.001152  0.001140
#
#     magnitude_vel_st  magnitude_horz_vel_st  magnitude_vert_vel_st  \
# 72          0.046842               0.029474               0.029731
# 73          0.088510               0.055965               0.055433
# 74          0.200499               0.124995               0.126018
# 75          0.150016               0.095055               0.095358
# 76          0.103493               0.066596               0.064488
#
#     magnitude_vel_dy  magnitude_horz_vel_dy  ...  magnitude_horz_jerk_dy  \
# 72          0.042719               0.026828  ...                0.000004
# ...

# %%
df1.describe()
# Out:
#        Unnamed: 0  no_strokes_st  no_strokes_dy   speed_st   speed_dy  \
# count   77.000000      77.000000      77.000000  77.000000  77.000000
# mean    38.000000      12.753247       9.012987   0.003215   0.003050
# std     22.371857      34.688143      23.865023   0.008312   0.007464
# min      0.000000       0.000000       0.000000   0.000000   0.000000
# 25%     19.000000       2.000000       2.000000   0.000014   0.000012
# 50%     38.000000       2.000000       2.000000   0.001201   0.001194
# 75%     57.000000       8.000000       6.000000   0.003287   0.003440
# max     76.000000     286.000000     176.000000   0.069104   0.061284
#
#        magnitude_vel_st  magnitude_horz_vel_st  magnitude_vert_vel_st  \
# count         77.000000              77.000000              77.000000
# mean           0.140580               0.093403               0.084502
# std            0.103393               0.071022               0.064026
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              77 non-null     int64
#  1   no_strokes_st           77 non-null     float64
#  2   no_strokes_dy           77 non-null     float64
#  3   speed_st                77 non-null     float64
#  4   speed_dy                77 non-null     float64
#  5   magnitude_vel_st        77 non-null     float64
#  6   magnitude_horz_vel_st   77 non-null     float64
#  7   magnitude_vert_vel_st   77 non-null     float64
#  8   magnitude_vel_dy        77 non-null     float64
#  9   magnitude_horz_vel_dy   77 non-null     float64
#  10  magnitude_vert_vel_dy   77 non-null     float64
#  11  magnitude_acc_st        77 non-null     float64
#  12  magnitude_horz_acc_st   77 non-null     float64
#  13  magnitude_vert_acc_st   77 non-null     float64
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                0
# no_strokes_st             0
# no_strokes_dy             0
# speed_st                  0
# speed_dy                  0
# magnitude_vel_st          0
# magnitude_horz_vel_st     0
# magnitude_vert_vel_st     0
# magnitude_vel_dy          0
# magnitude_horz_vel_dy     0
# magnitude_vert_vel_dy     0
# magnitude_acc_st          0
# magnitude_horz_acc_st     0
# magnitude_vert_acc_st     0
# magnitude_acc_dy          0
# magnitude_horz_acc_dy     0
# magnitude_vert_acc_dy     0
# magnitude_jerk_st         0
# magnitude_horz_jerk_st    0
# magnitude_vert_jerk_st    0
# magnitude_jerk_dy         0
# magnitude_horz_jerk_dy    0
# magnitude_vert_jerk_dy    0
# ncv_st                    0
# ncv_dy                    0
# nca_st                    0
# nca_dy                    0
# in_air_stcp               0
# on_surface_st             0
# on_surface_dy             0
# target                    0
# dtype: int64

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'no_strokes_st'}>,
#         <Axes: title={'center': 'no_strokes_dy'}>,
#         <Axes: title={'center': 'speed_st'}>,
#         <Axes: title={'center': 'speed_dy'}>,
#         <Axes: title={'center': 'magnitude_vel_st'}>],
#        [<Axes: title={'center': 'magnitude_horz_vel_st'}>,
#         <Axes: title={'center': 'magnitude_vert_vel_st'}>,
#         <Axes: title={'center': 'magnitude_vel_dy'}>,
#         <Axes: title={'center': 'magnitude_horz_vel_dy'}>,
#         <Axes: title={'center': 'magnitude_vert_vel_dy'}>,
#         <Axes: title={'center': 'magnitude_acc_st'}>],
#        [<Axes: title={'center': 'magnitude_horz_acc_st'}>,
#         <Axes: title={'center': 'magnitude_vert_acc_st'}>,
#         <Axes: title={'center': 'magnitude_acc_dy'}>,
#         <Axes: title={'center': 'magnitude_horz_acc_dy'}>,
#         <Axes: title={'center': 'magnitude_vert_acc_dy'}>,
# ...

# %%
df1.shape
# Out:
# (77, 31)

# %%
X = df1.drop("target",axis = 1)
y = df1["target"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.05,random_state = 20, stratify = y)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
pred = model.predict(X_test)
pred
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([0., 1., 1., 1.])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred,y_test)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00         1
#          1.0       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
pred1 = model.predict([[65,	2,	2,	0.069103998,	0.061283587,	0.091483924,	0.057594069,	0.05825919,	0.089721493,	0.056244262,	0.057435877,	0.000362649,	0.000203359,	0.000245521,	0.000332545,	0.000219027,	0.000197556,	8.45E-06,	4.67E-06,	5.92E-06,	7.20E-06,	4.89E-06,	4.15E-06,	255.125,	282,	70.75,	140,	0,	2994,	3064]])
if pred1 == 1:
    print("PERSON HAS BEEN DIAGONISED WITH PARKINSON'S DISEASE")
else:
    print("PERSON  IS SAFE FROM PARKINSON'S DISEASE")
# Out:
# PERSON  IS SAFE FROM PARKINSON'S DISEASE
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#KNN Algorithm 
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
#checking the validation score or test score 
print('Validation accuaracy score with KNN is',accuracy_score(y_test,pred))
# Out:
# Validation accuaracy score with KNN is 0.75
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
pred1=result.predict([[]])
pred1
